# %%
import tkinter
from tkinter import *
from tkinter import filedialog 
import pandas as pd
import numpy as np

import time

def edit_distance(s1, s2):
    """Compute the edit distance between two strings."""
    m, n = len(s1), len(s2)
    dp = np.zeros((m + 1, n + 1))
    for i in range(m + 1):
        dp[i, 0] = i
    for j in range(n + 1):
        dp[0, j] = j
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i, j] = dp[i - 1, j - 1]
            else:
                dp[i, j] = 1 + min(dp[i - 1, j], dp[i, j - 1], dp[i - 1, j - 1])
    return dp[m, n]

# %%
def upload_file():
    file=filedialog.askopenfilename(title="Select file" , filetypes=[("All files", '*.*'),("CSV files", '.csv')])

    if(file):
        lbl_my_file=Label(window, text="File read!", font=("arial", 12, "bold") )
        lbl_my_file.pack()
        
        comparison=0
        threshold=10
        chunk_size=100
        duplicate_list=[]
        count=0
        output_list = []
        
        df=pd.read_csv(file, infer_datetime_format=True)
        file_name.set(file)
        df["name"] = df["name"].str.replace(" ", "")
        std = df[['id', 'name', 'age', 'age_unit', 'province_id', 'district_id', 'municipality_id', 'tole', 'ward', 'caste', 'sex']].values
#         print(std)
        df['std_att'] = df.apply(lambda row: str(row['name']) + str(row['age']) + str(row['age_unit']) + str(row['province_id']) + str(row['district_id']) + str(row['municipality_id']) + str(row['tole']) + str(row['ward']) + str(row['caste']) + str(row['sex']), axis=1)
#         print(df['std_att'])
        std_att = df['name'].astype(str) + df['age'].astype(str) + df['age_unit'].astype(str) + df['province_id'].astype(str) + df['district_id'].astype(str) + df['municipality_id'].astype(str) + df['tole'].astype(str) + df['ward'].astype(str) + df['caste'].astype(str) + df['sex'].astype(str)
       
#         for index, row in df.iterrows():
#             print(f"ID: {row['id']}, std_att: {row['std_att']}")
    
    
    
        mylist = Text(window)
        mylist.pack(side=LEFT, fill=BOTH, expand=True)

        # create a scrollbar and associate it with the listbox
        sb = Scrollbar(window)
        sb.pack(side=RIGHT, fill=Y)
        mylist.config(yscrollcommand=sb.set)
        sb.config(command=mylist.yview)
            
            
        for i in range(0,  len(std_att), chunk_size):
            chunk = std_att.iloc[i:i+chunk_size]
            m = len(chunk)
            for j in range(m):
                for k in range(j + 1, m):
                    dist = edit_distance(chunk.iloc[j], chunk.iloc[k])
                    comparison=comparison+1
                    if dist <= threshold:
                        if i+j < len(chunk) and i+k < len(chunk):
                            output = f"Edit distance between {chunk.iloc[i+j]} and {chunk.iloc[i+k]}: {dist} \n"
#                             output_list.append(output)
                            print(output)
        print(len(output))
#                     count=count+1
#         print("number of duplicate: ", len(count))            
                    
        lbl_data=Label(window, text="Number of data in dataset:")
        lbl_data.pack()
        lbl_data_count=Label(window,text=len(std_att))
        lbl_data_count.pack()            
        lbl_comparison=Label(window, text="Number of Comparison")
        lbl_comparison.pack()            
        lbl=Label(window,text=comparison)
        lbl.pack()
        

        # create scrollbar
        sb = Scrollbar(window)
        sb.pack(side=BOTTOM, fill=BOTH)
        
        window.update_idletasks()
        canvas.config(scrollregion=canvas.bbox("all"))
#         end_time = time.time()
#         print(f"Total time taken: {end_time - start_time} seconds")

# %%
window=Tk()
window.geometry("1920x1080")
window.title("Data Redundancy Detection System")
title_lbl=Label(window, text="Upload .csv file", font=("arial", 30, "italic bold"),bd=7)
title_lbl.pack()
button=Button(window, text="Upload File", relief=RAISED,font=("arial", 15, "bold"), width=15, bg="light blue" ,command=upload_file)
button.pack()

file_name=StringVar()
file_data=StringVar()
my_file=StringVar()

lbl_name=Label(window, textvariable=file_name)
lbl_name.pack()


window.mainloop()
# Out:
# Edit distance between TekBahadurBista280769680Bajuda241 and TekBahadurBista280769680Bajuda241: 0.0
#
# Edit distance between NarayanPrasadTimilsena330769680kuika541 and BishnuPrasadTimilsena330769680Kuika541: 8.0
#
# Edit distance between ParashBista200769680Muli141 and DhurbaBista180769680Muli141: 8.0
#
# Edit distance between ParashBista200769680Muli141 and ParashBista190769680Muli141: 2.0
#
# Edit distance between ParashBista200769680Muli141 and KhemBista190769680Muli141: 8.0
#
# Edit distance between ParashBista200769680Muli141 and LaxmanBista180769680Muli141: 7.0
#
# Edit distance between ParashBista200769680Muli141 and HikmatBista170769680Muli141: 8.0
#
# Edit distance between ParashBista200769680Muli141 and NarBahadurBista620769680Muli141: 9.0
#
# Edit distance between DhurbaBista180769680Muli141 and ParashBista190769680Muli141: 7.0
#
# Edit distance between DhurbaBista180769680Muli141 and KhemBista190769680Muli141: 6.0
#
# Edit distance between DhurbaBista180769680Muli141 and LaxmanBista180769680Muli141: 6.0
#
# Edit distance between DhurbaBista180769680Muli141 and HikmatBista170769680Muli141: 7.0
#
# Edit distance between ParashBista190769680Muli141 and KhemBista190769680Muli141: 6.0
#
# Edit distance between ParashBista190769680Muli141 and LaxmanBista180769680Muli141: 6.0
#
# Edit distance between ParashBista190769680Muli141 and HikmatBista170769680Muli141: 7.0
#
# Edit distance between ParashBista190769680Muli141 and NarBahadurBista620769680Muli141: 9.0
#
# Edit distance between KhemBista190769680Muli141 and LaxmanBista180769680Muli141: 6.0
#
# Edit distance between KhemBista190769680Muli141 and HikmatBista170769680Muli141: 6.0
#
# Edit distance between KhemBista190769680Muli141 and KhemRajRegmi330769680Muli141: 10.0
#
# Edit distance between LaxmanBista180769680Muli141 and HikmatBista170769680Muli141: 5.0
#
# Edit distance between LaxmanBista180769680Muli141 and NarBahadurBista620769680Muli141: 10.0
#
# Edit distance between SherBahadurShahi280769680Birpath651 and SurjaShahi250769680Birpath652: 10.0
#
# Edit distance between KarishmaShahi250769680Birpath652 and SarswotiShahi101769680Birpath652: 9.0
#
# Edit distance between KarishmaShahi250769680Birpath652 and SurjaShahi250769680Birpath652: 6.0
#
# Edit distance between SarswotiShahi101769680Birpath652 and SurjaShahi250769680Birpath652: 9.0
#
# Edit distance between TankDhami390769683Malutol241 and NaurataDhami460769683Malutol242: 9.0
#
# Edit distance between NaurataDhami460769683Malutol242 and NaurataDhami460769683Binayak242: 7.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and KaranB.K270769680Mastabandali901: 5.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and SaritaB.K210769680Mastabandali902: 8.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and SapanaB.K111769680Mastabandali902: 10.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and BhimB.K80769680Mastabandali901: 7.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and RamitaB.K70769680Mastabandali902: 9.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and MinaB.K280769680Mastabandali902: 7.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and ManikaB.K140769680Mastabandali902: 9.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and DebuB.K500769680Mastabandali902: 8.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and TankB.K70769680Mastabandali901: 8.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and JhumaB.K600769680Mastabandali902: 8.0
#
# Edit distance between KeshabB.K220769680Mastabandali901 and TulsiB.K450769680Mastabandali902: 9.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and SaritaB.K210769680Mastabandali902: 6.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and SapanaB.K111769680Mastabandali902: 7.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and BhimB.K80769680Mastabandali901: 7.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and RamitaB.K70769680Mastabandali902: 7.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and MinaB.K280769680Mastabandali902: 6.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and ManikaB.K140769680Mastabandali902: 8.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and DebuB.K500769680Mastabandali902: 8.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and TankB.K70769680Mastabandali901: 5.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and JhumaB.K600769680Mastabandali902: 8.0
#
# Edit distance between KaranB.K270769680Mastabandali901 and TulsiB.K450769680Mastabandali902: 8.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and SapanaB.K111769680Mastabandali902: 5.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and BhimB.K80769680Mastabandali901: 8.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and RamitaB.K70769680Mastabandali902: 4.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and MinaB.K280769680Mastabandali902: 5.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and ManikaB.K140769680Mastabandali902: 5.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and DebuB.K500769680Mastabandali902: 8.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and TankB.K70769680Mastabandali901: 8.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 7.0
#
# Edit distance between SaritaB.K210769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 8.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and BhimB.K80769680Mastabandali901: 10.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and RamitaB.K70769680Mastabandali902: 7.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and MinaB.K280769680Mastabandali902: 7.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and ManikaB.K140769680Mastabandali902: 6.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and DebuB.K500769680Mastabandali902: 9.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and TankB.K70769680Mastabandali901: 8.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 8.0
#
# Edit distance between SapanaB.K111769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 9.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and RamitaB.K70769680Mastabandali902: 7.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and MinaB.K280769680Mastabandali902: 6.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and ManikaB.K140769680Mastabandali902: 8.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and DebuB.K500769680Mastabandali902: 7.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and TankB.K70769680Mastabandali901: 5.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and JhumaB.K600769680Mastabandali902: 6.0
#
# Edit distance between BhimB.K80769680Mastabandali901 and TulsiB.K450769680Mastabandali902: 8.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and MinaB.K280769680Mastabandali902: 6.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and ManikaB.K140769680Mastabandali902: 5.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and DebuB.K500769680Mastabandali902: 8.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and TankB.K70769680Mastabandali901: 6.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 7.0
#
# Edit distance between RamitaB.K70769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 8.0
#
# Edit distance between MinaB.K280769680Mastabandali902 and ManikaB.K140769680Mastabandali902: 5.0
#
# Edit distance between MinaB.K280769680Mastabandali902 and DebuB.K500769680Mastabandali902: 6.0
#
# Edit distance between MinaB.K280769680Mastabandali902 and TankB.K70769680Mastabandali901: 6.0
#
# Edit distance between MinaB.K280769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 6.0
#
# Edit distance between MinaB.K280769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 7.0
#
# Edit distance between ManikaB.K140769680Mastabandali902 and DebuB.K500769680Mastabandali902: 8.0
#
# Edit distance between ManikaB.K140769680Mastabandali902 and TankB.K70769680Mastabandali901: 6.0
#
# Edit distance between ManikaB.K140769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 7.0
#
# Edit distance between ManikaB.K140769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 8.0
#
# Edit distance between DebuB.K500769680Mastabandali902 and TankB.K70769680Mastabandali901: 7.0
#
# Edit distance between DebuB.K500769680Mastabandali902 and JhumaB.K600769680Mastabandali902: 6.0
#
# Edit distance between DebuB.K500769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 7.0
#
# Edit distance between TankB.K70769680Mastabandali901 and JhumaB.K600769680Mastabandali902: 8.0
#
# Edit distance between TankB.K70769680Mastabandali901 and TulsiB.K450769680Mastabandali902: 7.0
#
# Edit distance between JhumaB.K600769680Mastabandali902 and TulsiB.K450769680Mastabandali902: 7.0
# Edit distance between PadamRawal580769683Toli641 and JagatRawal440769683Toli641: 5.0
#
# Edit distance between PadamRawal580769683Toli641 and AkkalRawal450769683Toli641: 6.0
#
# Edit distance between PadamRawal580769683Toli641 and SuratRawal480769683Toli641: 5.0
#
# Edit distance between PadamRawal580769683Toli641 and PremRawal370769683Toli641: 5.0
#
# Edit distance between PadamRawal580769683Toli641 and DambarRawal480769683Toli641: 5.0
#
# Edit distance between PadamRawal580769683Toli641 and DanBahadurRawal370769683Toli641: 10.0
#
# Edit distance between PadamRawal580769683Toli641 and HarishRawal200769683Toli641: 7.0
#
# Edit distance between PadamRawal580769683Toli641 and BhimBahadurRawal550769683Toli641: 10.0
#
# Edit distance between PadamRawal580769683Toli641 and DharmaRawal370769683Toli642: 8.0
#
# Edit distance between PadamRawal580769683Toli641 and PansaraRawal250769683Toli642: 7.0
#
# Edit distance between PadamRawal580769683Toli641 and PansaraRawal360769683Toli642: 7.0
#
# Edit distance between PadamRawal580769683Toli641 and NirmalaRawal210769683Toli642: 9.0
#
# Edit distance between BisnaDeviRawal760769683Toli642 and DharmaRawal370769683Toli642: 10.0
#
# Edit distance between BisnaDeviRawal760769683Toli642 and PansaraRawal250769683Toli642: 10.0
#
# Edit distance between BisnaDeviRawal760769683Toli642 and PansaraRawal360769683Toli642: 9.0
#
# Edit distance between BisnaDeviRawal760769683Toli642 and BhumisaraRawal400769683Toli642: 10.0
#
# Edit distance between BisnaDeviRawal760769683Toli642 and NirmalaRawal210769683Toli642: 9.0
#
# Edit distance between ManeB.K370769683Toli601 and RenukaB.K320769683Toli602: 7.0
#
# Edit distance between ManeB.K370769683Toli601 and TulshiB.K140769683Toli602: 9.0
#
# Edit distance between ManeB.K370769683Toli601 and PremRawal370769683Toli641: 10.0
#
# Edit distance between ManeB.K370769683Toli601 and DilipBdr.B.K320769683Toli601: 10.0
#
# Edit distance between ManeB.K370769683Toli601 and PremB.K230769683Toli601: 6.0
#
# Edit distance between ManeB.K370769683Toli601 and KeshebB.K410769683Toli601: 7.0
#
# Edit distance between RenukaB.K320769683Toli602 and TulshiB.K140769683Toli602: 8.0
#
# Edit distance between RenukaB.K320769683Toli602 and DilipBdr.B.K320769683Toli601: 10.0
#
# Edit distance between RenukaB.K320769683Toli602 and MenukaBatala220769683Toli642: 8.0
#
# Edit distance between RenukaB.K320769683Toli602 and PremB.K230769683Toli601: 9.0
#
# Edit distance between RenukaB.K320769683Toli602 and KeshebB.K410769683Toli601: 8.0
#
# Edit distance between TulshiB.K140769683Toli602 and PremB.K230769683Toli601: 9.0
#
# Edit distance between TulshiB.K140769683Toli602 and KeshebB.K410769683Toli601: 8.0
#
# Edit distance between JagatRawal440769683Toli641 and AkkalRawal450769683Toli641: 5.0
#
# Edit distance between JagatRawal440769683Toli641 and SuratRawal480769683Toli641: 4.0
#
# Edit distance between JagatRawal440769683Toli641 and PremRawal370769683Toli641: 7.0
#
# Edit distance between JagatRawal440769683Toli641 and DambarRawal480769683Toli641: 5.0
#
# Edit distance between JagatRawal440769683Toli641 and DanBahadurRawal370769683Toli641: 10.0
#
# Edit distance between JagatRawal440769683Toli641 and HarishRawal200769683Toli641: 7.0
#
# Edit distance between JagatRawal440769683Toli641 and DharmaRawal370769683Toli642: 8.0
#
# Edit distance between JagatRawal440769683Toli641 and PansaraRawal250769683Toli642: 8.0
#
# Edit distance between JagatRawal440769683Toli641 and PansaraRawal360769683Toli642: 8.0
#
# Edit distance between JagatRawal440769683Toli641 and BhumisaraRawal400769683Toli642: 10.0
#
# Edit distance between JagatRawal440769683Toli641 and NirmalaRawal210769683Toli642: 9.0
#
# Edit distance between AkkalRawal450769683Toli641 and SuratRawal480769683Toli641: 5.0
#
# Edit distance between AkkalRawal450769683Toli641 and PremRawal370769683Toli641: 7.0
#
# Edit distance between AkkalRawal450769683Toli641 and DambarRawal480769683Toli641: 6.0
#
# Edit distance between AkkalRawal450769683Toli641 and HarishRawal200769683Toli641: 8.0
#
# Edit distance between AkkalRawal450769683Toli641 and DharmaRawal370769683Toli642: 9.0
#
# Edit distance between AkkalRawal450769683Toli641 and PansaraRawal250769683Toli642: 8.0
#
# Edit distance between AkkalRawal450769683Toli641 and PansaraRawal360769683Toli642: 9.0
#
# Edit distance between AkkalRawal450769683Toli641 and BhumisaraRawal400769683Toli642: 10.0
#
# Edit distance between AkkalRawal450769683Toli641 and NirmalaRawal210769683Toli642: 8.0
#
# Edit distance between SuratRawal480769683Toli641 and PremRawal370769683Toli641: 6.0
#
# Edit distance between SuratRawal480769683Toli641 and DambarRawal480769683Toli641: 5.0
#
# Edit distance between SuratRawal480769683Toli641 and HarishRawal200769683Toli641: 7.0
#
# Edit distance between SuratRawal480769683Toli641 and DharmaRawal370769683Toli642: 8.0
#
# Edit distance between SuratRawal480769683Toli641 and PansaraRawal250769683Toli642: 9.0
#
# Edit distance between SuratRawal480769683Toli641 and PansaraRawal360769683Toli642: 9.0
#
# Edit distance between SuratRawal480769683Toli641 and BhumisaraRawal400769683Toli642: 9.0
#
# Edit distance between SuratRawal480769683Toli641 and NirmalaRawal210769683Toli642: 8.0
#
# Edit distance between PremRawal370769683Toli641 and DambarRawal480769683Toli641: 8.0
#
# Edit distance between PremRawal370769683Toli641 and DanBahadurRawal370769683Toli641: 10.0
#
# Edit distance between PremRawal370769683Toli641 and HarishRawal200769683Toli641: 7.0
#
# Edit distance between PremRawal370769683Toli641 and DharmaRawal370769683Toli642: 6.0
#
# Edit distance between PremRawal370769683Toli641 and PansaraRawal250769683Toli642: 9.0
#
# Edit distance between PremRawal370769683Toli641 and PansaraRawal360769683Toli642: 8.0
#
# Edit distance between PremRawal370769683Toli641 and PremB.K230769683Toli601: 7.0
#
# Edit distance between PremRawal370769683Toli641 and NirmalaRawal210769683Toli642: 9.0
#
# Edit distance between DambarRawal480769683Toli641 and DanBahadurRawal370769683Toli641: 8.0
#
# Edit distance between DambarRawal480769683Toli641 and HarishRawal200769683Toli641: 7.0
#
# Edit distance between DambarRawal480769683Toli641 and BhimBahadurRawal550769683Toli641: 10.0
#
# Edit distance between DambarRawal480769683Toli641 and DharmaRawal370769683Toli642: 7.0
#
# Edit distance between DambarRawal480769683Toli641 and PansaraRawal250769683Toli642: 7.0
#
# Edit distance between DambarRawal480769683Toli641 and PansaraRawal360769683Toli642: 7.0
#
# Edit distance between DambarRawal480769683Toli641 and BhumisaraRawal400769683Toli642: 8.0
#
# Edit distance between DambarRawal480769683Toli641 and NirmalaRawal210769683Toli642: 9.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and BhimBahadurKami330769683Toli601: 10.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and HarishRawal200769683Toli641: 10.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and BhimBahadurRawal550769683Toli641: 6.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and DharmaRawal370769683Toli642: 8.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and PansaraRawal250769683Toli642: 9.0
#
# Edit distance between DanBahadurRawal370769683Toli641 and PansaraRawal360769683Toli642: 8.0
#
# Edit distance between BhimBahadurKami330769683Toli601 and BhimBahadurRawal550769683Toli641: 7.0
#
# Edit distance between HarishRawal200769683Toli641 and DharmaRawal370769683Toli642: 8.0
#
# Edit distance between HarishRawal200769683Toli641 and PansaraRawal250769683Toli642: 8.0
#
# Edit distance between HarishRawal200769683Toli641 and PansaraRawal360769683Toli642: 9.0
#
# Edit distance between HarishRawal200769683Toli641 and BhumisaraRawal400769683Toli642: 9.0
#
# Edit distance between HarishRawal200769683Toli641 and NirmalaRawal210769683Toli642: 8.0
#
# Edit distance between BhimBahadurRawal550769683Toli641 and BhumisaraRawal400769683Toli642: 10.0
#
# Edit distance between DharmaRawal370769683Toli642 and PansaraRawal250769683Toli642: 7.0
#
# Edit distance between DharmaRawal370769683Toli642 and PansaraRawal360769683Toli642: 6.0
#
# Edit distance between DharmaRawal370769683Toli642 and BhumisaraRawal400769683Toli642: 8.0
#
# Edit distance between DharmaRawal370769683Toli642 and MenukaBatala220769683Toli642: 10.0
#
# Edit distance between DharmaRawal370769683Toli642 and NirmalaRawal210769683Toli642: 7.0
#
# Edit distance between NirmalaKhatri250769683Toli642 and PansaraRawal250769683Toli642: 10.0
#
# Edit distance between NirmalaKhatri250769683Toli642 and NirmalaRawal210769683Toli642: 6.0
#
# Edit distance between PansaraRawal250769683Toli642 and PansaraRawal360769683Toli642: 2.0
#
# Edit distance between PansaraRawal250769683Toli642 and BhumisaraRawal400769683Toli642: 7.0
#
# Edit distance between PansaraRawal250769683Toli642 and MenukaBatala220769683Toli642: 9.0
#
# Edit distance between PansaraRawal250769683Toli642 and NirmalaRawal210769683Toli642: 6.0
#
# Edit distance between PansaraRawal360769683Toli642 and BhumisaraRawal400769683Toli642: 7.0
#
# Edit distance between PansaraRawal360769683Toli642 and MenukaBatala220769683Toli642: 10.0
#
# Edit distance between PansaraRawal360769683Toli642 and NirmalaRawal210769683Toli642: 7.0
#
# Edit distance between BhumisaraRawal400769683Toli642 and NirmalaRawal210769683Toli642: 8.0
# Edit distance between MenukaBatala220769683Toli642 and NirmalaRawal210769683Toli642: 10.0
#
# Edit distance between PremB.K230769683Toli601 and KeshebB.K410769683Toli601: 7.0
#
# Edit distance between DilipDhami310769683Binayak241 and PremDholi370769683Binayak201: 9.0
#
# Edit distance between DilipDhami310769683Binayak241 and NaurataDhami460769683Binayak242: 10.0
#
# Edit distance between DilipDhami310769683Binayak241 and PankhaDhami230769683Binayak242: 9.0
#
# Edit distance between NaurataDhami460769683Binayak242 and PankhaDhami230769683Binayak242: 7.0
#
# Edit distance between KalamBahadurShahi380769683Layati541 and KalamShahi190769683Layati551: 10.0
#
# Edit distance between KalamBahadurShahi380769683Layati541 and KalamShahi220769683Layati551: 10.0
#
# Edit distance between PremShahi220769683Layati551 and NirmalaShahi210769683Latati552: 9.0
#
# Edit distance between PremShahi220769683Layati551 and DikshyaShahi20769683Layati552: 9.0
#
# Edit distance between PremShahi220769683Layati551 and YoubrajShahi240769683Layati551: 7.0
#
# Edit distance between PremShahi220769683Layati551 and GauriShahi220769683Layati552: 6.0
#
# Edit distance between PremShahi220769683Layati551 and AayushaShahi10769683Layati551: 9.0
#
# Edit distance between PremShahi220769683Layati551 and KalamShahi190769683Layati551: 6.0
#
# Edit distance between PremShahi220769683Layati551 and RameshShahi250769683Layati551: 6.0
#
# Edit distance between PremShahi220769683Layati551 and KalamShahi220769683Layati551: 4.0
#
# Edit distance between PremShahi220769683Layati551 and NagendraShahi340769683Layati551: 9.0
#
# Edit distance between NirmalaShahi210769683Latati552 and DikshyaShahi20769683Layati552: 7.0
#
# Edit distance between NirmalaShahi210769683Latati552 and YoubrajShahi240769683Layati551: 10.0
#
# Edit distance between NirmalaShahi210769683Latati552 and GauriShahi220769683Layati552: 9.0
#
# Edit distance between NirmalaShahi210769683Latati552 and AayushaShahi10769683Layati551: 9.0
#
# Edit distance between NirmalaShahi210769683Latati552 and KalamShahi190769683Layati551: 9.0
#
# Edit distance between NirmalaShahi210769683Latati552 and RameshShahi250769683Layati551: 9.0
#
# Edit distance between NirmalaShahi210769683Latati552 and KalamShahi220769683Layati551: 8.0
#
# Edit distance between NirmalaShahi210769683Latati552 and NagendraShahi340769683Layati551: 10.0
#
# Edit distance between DikshyaShahi20769683Layati552 and YoubrajShahi240769683Layati551: 9.0
#
# Edit distance between DikshyaShahi20769683Layati552 and GauriShahi220769683Layati552: 8.0
#
# Edit distance between DikshyaShahi20769683Layati552 and AayushaShahi10769683Layati551: 7.0
#
# Edit distance between DikshyaShahi20769683Layati552 and KalamShahi190769683Layati551: 10.0
#
# Edit distance between DikshyaShahi20769683Layati552 and RameshShahi250769683Layati551: 8.0
#
# Edit distance between DikshyaShahi20769683Layati552 and KalamShahi220769683Layati551: 9.0
#
# Edit distance between DikshyaShahi20769683Layati552 and NagendraShahi340769683Layati551: 10.0
#
# Edit distance between YoubrajShahi240769683Layati551 and GauriShahi220769683Layati552: 7.0
#
# Edit distance between YoubrajShahi240769683Layati551 and AayushaShahi10769683Layati551: 8.0
#
# Edit distance between YoubrajShahi240769683Layati551 and KalamShahi190769683Layati551: 8.0
#
# Edit distance between YoubrajShahi240769683Layati551 and RameshShahi250769683Layati551: 8.0
#
# Edit distance between YoubrajShahi240769683Layati551 and KalamShahi220769683Layati551: 7.0
#
# Edit distance between YoubrajShahi240769683Layati551 and NagendraShahi340769683Layati551: 8.0
#
# Edit distance between GauriShahi220769683Layati552 and AayushaShahi10769683Layati551: 8.0
#
# Edit distance between GauriShahi220769683Layati552 and KalamShahi190769683Layati551: 7.0
#
# Edit distance between GauriShahi220769683Layati552 and RameshShahi250769683Layati551: 7.0
#
# Edit distance between GauriShahi220769683Layati552 and KalamShahi220769683Layati551: 5.0
#
# Edit distance between GauriShahi220769683Layati552 and NagendraShahi340769683Layati551: 9.0
#
# Edit distance between AayushaShahi10769683Layati551 and KalamShahi190769683Layati551: 7.0
#
# Edit distance between AayushaShahi10769683Layati551 and RameshShahi250769683Layati551: 6.0
#
# Edit distance between AayushaShahi10769683Layati551 and KalamShahi220769683Layati551: 8.0
#
# Edit distance between AayushaShahi10769683Layati551 and NagendraShahi340769683Layati551: 8.0
#
# Edit distance between KalamShahi190769683Layati551 and RameshShahi250769683Layati551: 7.0
#
# Edit distance between KalamShahi190769683Layati551 and KalamShahi220769683Layati551: 2.0
#
# Edit distance between KalamShahi190769683Layati551 and NagendraShahi340769683Layati551: 9.0
#
# Edit distance between RameshShahi250769683Layati551 and KalamShahi220769683Layati551: 6.0
#
# Edit distance between RameshShahi250769683Layati551 and NagendraShahi340769683Layati551: 8.0
#
# Edit distance between KalamShahi220769683Layati551 and NagendraShahi340769683Layati551: 9.0
#
# Edit distance between BharatRawal310769683Pulletola741 and BrendraRawal250769683Pulletola741: 7.0
#
# Edit distance between BharatRawal310769683Pulletola741 and NikitaRawal250769683Pulletola742: 9.0
#
# Edit distance between BharatRawal310769683Pulletola741 and PrinceRawal40769683Pulletola741: 8.0
#
# Edit distance between BharatRawal310769683Pulletola741 and SagarRawal220769683Pulletola741: 6.0
#
# Edit distance between BharatRawal310769683Pulletola741 and RajeshRawal200769683Pulletola741: 8.0
#
# Edit distance between BharatRawal310769683Pulletola741 and KeneshaRawal190769683Pulletola742: 10.0
#
# Edit distance between AkkalB.K220769683Pulletola701 and SagarRawal220769683Pulletola741: 10.0
#
# Edit distance between AkkalB.K220769683Pulletola701 and BinodB.K.180769683Pulletola701: 8.0
#
# Edit distance between AkkalB.K220769683Pulletola701 and RajendraB.K190769683Pulletola701: 10.0
#
# Edit distance between BrendraRawal250769683Pulletola741 and NikitaRawal250769683Pulletola742: 7.0
#
# Edit distance between BrendraRawal250769683Pulletola741 and PrinceRawal40769683Pulletola741: 7.0
#
# Edit distance between BrendraRawal250769683Pulletola741 and SagarRawal220769683Pulletola741: 7.0
#
# Edit distance between BrendraRawal250769683Pulletola741 and RajeshRawal200769683Pulletola741: 8.0
#
# Edit distance between BrendraRawal250769683Pulletola741 and KeneshaRawal190769683Pulletola742: 8.0
#
# Edit distance between NikitaRawal250769683Pulletola742 and PrinceRawal40769683Pulletola741: 9.0
#
# Edit distance between NikitaRawal250769683Pulletola742 and SagarRawal220769683Pulletola741: 8.0
#
# Edit distance between NikitaRawal250769683Pulletola742 and RajeshRawal200769683Pulletola741: 8.0
#
# Edit distance between NikitaRawal250769683Pulletola742 and KeneshaRawal190769683Pulletola742: 8.0
#
# Edit distance between PrinceRawal40769683Pulletola741 and SagarRawal220769683Pulletola741: 8.0
#
# Edit distance between PrinceRawal40769683Pulletola741 and RajeshRawal200769683Pulletola741: 8.0
#
# Edit distance between PrinceRawal40769683Pulletola741 and KeneshaRawal190769683Pulletola742: 10.0
#
# Edit distance between SagarRawal220769683Pulletola741 and RajeshRawal200769683Pulletola741: 6.0
#
# Edit distance between SagarRawal220769683Pulletola741 and KeneshaRawal190769683Pulletola742: 10.0
#
# Edit distance between RajeshRawal200769683Pulletola741 and KeneshaRawal190769683Pulletola742: 7.0
#
# Edit distance between RajeshRawal200769683Pulletola741 and RajendraB.K190769683Pulletola701: 9.0
#
# Edit distance between BinodB.K.180769683Pulletola701 and RajendraB.K190769683Pulletola701: 9.0
#
# 96
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_9956\859566417.py", line 70, in upload_file
#     canvas.config(scrollregion=canvas.bbox("all"))
# NameError: name 'canvas' is not defined
