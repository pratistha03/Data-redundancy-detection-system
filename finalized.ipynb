# %%
import tkinter
from tkinter import *
from tkinter import filedialog 
import pandas as pd
import numpy as np

import time

def edit_distance(s1, s2):
    m = len(s1)
    n = len(s2)

    # initialize the matrix
    d = [[0] * (n + 1) for i in range(m + 1)]

    # fill the first row and first column
    for i in range(1, m + 1):
        d[i][0] = i
    for j in range(1, n + 1):
        d[0][j] = j

    # fill the rest of the matrix
    for j in range(1, n + 1):
        for i in range(1, m + 1):
            if s1[i - 1] == s2[j - 1]:
                d[i][j] = d[i - 1][j - 1]
            else:
                d[i][j] = min(d[i - 1][j], d[i][j - 1], d[i - 1][j - 1]) + 1

    # return the final value in the matrix
    return d[m][n]

 


def count_duplicates(records):
    count_dict = {}

    for row in records:
        record = tuple(row[1:]) # discard column 1

        if record in count_dict:
            count_dict[record] ['count']+= 1
            count_dict[record]['ids'].append(row[0]) # add ID to list of IDs

        else:
            count_dict[record] = {'count': 1, 'ids': [row[0]]}

    duplicates = []
    total=0         
    for record, count_dict in count_dict.items():
         if count_dict['count'] > 1:
            duplicates.append(f"IDs: {', '.join(str(id) for id in count_dict['ids'])}, {record}: duplicate count: {count_dict['count']} ")
            total=total+count_dict['count']
#     print("Total duplicates: ", total)
    lbl_total=Label(window, text="Number of Duplicates")
    lbl_total.pack()            
    lbl_total_count=Label(window,text=total)
    lbl_total_count.pack()
    return duplicates

# %%
def upload_file():
    file=filedialog.askopenfilename(title="Select file" , filetypes=[("All files", '*.*'),("CSV files", '.csv')])

    if(file):
        lbl_my_file=Label(window, text="File read!", font=("arial", 12, "bold") )
        lbl_my_file.pack()
        
        comparison=0
        threshold=10
        chunk_size=50
        
        canvas = None
        probable=[]
        matching_ids=[]
        
        
        df = pd.read_csv(file, infer_datetime_format=True, encoding='ISO-8859-1')
        
        file_name.set(file)
        df["name"] = df["name"].str.replace(" ", "")
        std = df[['id', 'name', 'age', 'age_unit', 'province_id', 'district_id', 'municipality_id', 'tole', 'ward', 'caste', 'sex']].values
#         print(std)
        df['std_att'] = df.apply(lambda row: str(row['name']) + str(row['age']) + str(row['age_unit']) + str(row['province_id']) + str(row['district_id']) + str(row['municipality_id']) + str(row['tole']) + str(row['ward']) + str(row['caste']) + str(row['sex']), axis=1)
#         print(df['std_att'])
        std_att = df['name'].astype(str) + df['age'].astype(str) + df['age_unit'].astype(str) + df['province_id'].astype(str) + df['district_id'].astype(str) + df['municipality_id'].astype(str) + df['tole'].astype(str) + df['ward'].astype(str) + df['caste'].astype(str) + df['sex'].astype(str)
        print("............Dataset..........")
        for index, row in df.iterrows():
            a=f"ID: {row['id']}, std_att: {row['std_att']}"
            print(a)
    
    
    
        mylist = Text(window)
        mylist.pack(side=LEFT, fill=BOTH, expand=True)

        # create a scrollbar and associate it with the listbox
        sb = Scrollbar(window)
        sb.pack(side=RIGHT, fill=Y)
        mylist.config(yscrollcommand=sb.set)
        sb.config(command=mylist.yview)
        
        unique_ids = [] # list to store unique IDs
        unique_std_att = [] # list to store corresponding unique std_att values

        for i in range(0, len(df), chunk_size):
            chunk = df.iloc[i:i+chunk_size]
            std_chunk=std_att.iloc[i:i+chunk_size]
            print(type(chunk))  # add this line to check the data type
            m = len(chunk)
            for j in range(m):
                for k in range(j + 1, m):
                    id_j = str(chunk.iloc[j]['id'])
                    id_k = str(chunk.iloc[k]['id'])
                    dist = edit_distance(std_chunk.iloc[j], std_chunk.iloc[k])
                    comparison += 1 # m * (m - 1) / 2
                    if dist <= threshold:
                        pair = (dist, f"Edit distance between ({id_j}){chunk.iloc[j]['std_att']} and ({id_k}){chunk.iloc[k]['std_att']} : {dist}")
                        probable.append(pair)    
                        
                        if id_j not in unique_ids:
                            unique_ids.append(id_j)
                            unique_std_att.append((chunk.iloc[j]['id'], chunk.iloc[j]['std_att']))
                        if id_k not in unique_ids:
                            unique_ids.append(id_k)
                            unique_std_att.append((chunk.iloc[k]['id'], chunk.iloc[k]['std_att']))
                            
        print("...........Edit Distance in Sorted order.............")                    
        probable = sorted(probable, key=lambda x: x[0]) # sort by distance
        for pair in probable:
            print(pair[1])
                
                
        print("..........Dataset within the edit distance with unique id.............")
        print(unique_std_att)
        print("Count: ", len(unique_std_att))
        
#         print("duplicates: ")
        duplicates = count_duplicates(unique_std_att)
        for i in range(len(duplicates)):
#             print(f"{duplicates[i]}")
            mylist.insert(END,f"{i+1}: {duplicates[i]}\n")
        

            
        lbl_data=Label(window, text="Number of data in dataset:")
        lbl_data.pack()
        lbl_data_count=Label(window,text=len(std_att))
        lbl_data_count.pack()            
        lbl_comparison=Label(window, text="Number of Comparison")
        lbl_comparison.pack()            
        lbl=Label(window,text=comparison)
        lbl.pack()
        

        # create scrollbar
        sb = Scrollbar(window)
        sb.pack(side=BOTTOM, fill=BOTH)
        
        window.update_idletasks()
        canvas.config(scrollregion=canvas.bbox("all"))
#         end_time = time.time()
#         print(f"Total time taken: {end_time - start_time} seconds")

# %%
window=Tk()
window.geometry("1920x1080")
window.title("Data Redundancy Detection System")
title_lbl=Label(window, text="Upload .csv file", font=("arial", 30, "italic bold"),bd=7)
title_lbl.pack()
button=Button(window, text="Upload File", relief=RAISED,font=("arial", 15, "bold"), width=15, bg="light blue" ,command=upload_file)
button.pack()

file_name=StringVar()
file_data=StringVar()
my_file=StringVar()

lbl_name=Label(window, textvariable=file_name)
lbl_name.pack()


window.mainloop()
# Out:
# ............Dataset..........
# ID: 121, std_att: TekBahadurBista280769680Bajuda241
# ID: 122, std_att: TekBahadurBista280769680Bajuda241
# ID: 125, std_att: PratimaNeupane190329314Churkharka442
# ID: 142, std_att: BalBd.Sarki330771705khalla401
# ID: 143, std_att: DipakSinghSarki440771705khalla401
# ID: 144, std_att: ShreeKoli320771705khalla401
# ID: 146, std_att: GaurabBahadurBist240772717jhalari1041
# ID: 147, std_att: KrishaSharki20771703jagatpur602
# ID: 148, std_att: NarayanPrasadTimilsena330769680kuika541
# ID: 151, std_att: sumanChapagai280321239manthali141
# ID: 180, std_att: BishnuPrasadTimilsena330769680Kuika541
# ID: 181, std_att: PuranKarki300769680Bayala341
# ID: 182, std_att: ParashBista200769680Muli141
# ID: 183, std_att: JivanRajUpadhyay350769679Ghodasain841
# ID: 184, std_att: TapendraUpadhyay320769679Lekhgaun841
# ID: 185, std_att: DhurbaBista180769680Muli141
# ID: 186, std_att: ParashBista190769680Muli141
# ID: 187, std_att: KhemBista190769680Muli141
# ID: 188, std_att: LaxmanBista180769680Muli141
# ID: 189, std_att: HikmatBista170769680Muli141
# ID: 190, std_att: RabiPrasadJaisi200769680Ghodasain1041
# ID: 191, std_att: NarBahadurBista620769680Muli141
# ID: 192, std_att: JanakBista540769680Dhanku841
# ID: 193, std_att: TopendraKumarShahi430769680Birpath651
# ID: 194, std_att: KhemRajRegmi330769680Muli141
# ID: 195, std_att: SherBahadurShahi280769680Birpath651
# ID: 196, std_att: KarishmaShahi250769680Birpath652
# ID: 197, std_att: SarswotiShahi101769680Birpath652
# ID: 198, std_att: SurjaShahi250769680Birpath652
# ID: 199, std_att: TankDhami390769683Malutol241
# ID: 200, std_att: NaurataDhami460769683Malutol242
# ID: 201, std_att: KeshabB.K220769680Mastabandali901
# ID: 202, std_att: KaranB.K270769680Mastabandali901
# ID: 203, std_att: SaritaB.K210769680Mastabandali902
# ID: 204, std_att: SapanaB.K111769680Mastabandali902
# ID: 205, std_att: BhimB.K80769680Mastabandali901
# ID: 206, std_att: RamitaB.K70769680Mastabandali902
# ID: 207, std_att: MinaB.K280769680Mastabandali902
# ID: 208, std_att: ManikaB.K140769680Mastabandali902
# ID: 209, std_att: DebuB.K500769680Mastabandali902
# ID: 210, std_att: TankB.K70769680Mastabandali901
# ID: 211, std_att: JhumaB.K600769680Mastabandali902
# ID: 212, std_att: TulsiB.K450769680Mastabandali902
# ID: 213, std_att: TularamB.K320769680Muli101
# ID: 214, std_att: KumbaPrasadDhakal320769680Muli141
# ID: 215, std_att: PadamRawal580769683Toli641
# ID: 216, std_att: BisnaDeviRawal760769683Toli642
# ID: 217, std_att: RangiDeviBhandari770769683Toli642
# ID: 218, std_att: ManeB.K370769683Toli601
# ID: 219, std_att: RenukaB.K320769683Toli602
# <class 'pandas.core.frame.DataFrame'>
# ...........Edit Distance in Sorted order.............
# Edit distance between (121)TekBahadurBista280769680Bajuda241 and (122)TekBahadurBista280769680Bajuda241 : 0
# Edit distance between (182)ParashBista200769680Muli141 and (186)ParashBista190769680Muli141 : 2
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (206)RamitaB.K70769680Mastabandali902 : 4
# Edit distance between (188)LaxmanBista180769680Muli141 and (189)HikmatBista170769680Muli141 : 5
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (202)KaranB.K270769680Mastabandali901 : 5
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (210)TankB.K70769680Mastabandali901 : 5
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (204)SapanaB.K111769680Mastabandali902 : 5
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (207)MinaB.K280769680Mastabandali902 : 5
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (208)ManikaB.K140769680Mastabandali902 : 5
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (210)TankB.K70769680Mastabandali901 : 5
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (208)ManikaB.K140769680Mastabandali902 : 5
# Edit distance between (207)MinaB.K280769680Mastabandali902 and (208)ManikaB.K140769680Mastabandali902 : 5
# Edit distance between (185)DhurbaBista180769680Muli141 and (187)KhemBista190769680Muli141 : 6
# Edit distance between (185)DhurbaBista180769680Muli141 and (188)LaxmanBista180769680Muli141 : 6
# Edit distance between (186)ParashBista190769680Muli141 and (187)KhemBista190769680Muli141 : 6
# Edit distance between (186)ParashBista190769680Muli141 and (188)LaxmanBista180769680Muli141 : 6
# Edit distance between (187)KhemBista190769680Muli141 and (188)LaxmanBista180769680Muli141 : 6
# Edit distance between (187)KhemBista190769680Muli141 and (189)HikmatBista170769680Muli141 : 6
# Edit distance between (196)KarishmaShahi250769680Birpath652 and (198)SurjaShahi250769680Birpath652 : 6
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (203)SaritaB.K210769680Mastabandali902 : 6
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (207)MinaB.K280769680Mastabandali902 : 6
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (208)ManikaB.K140769680Mastabandali902 : 6
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (207)MinaB.K280769680Mastabandali902 : 6
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (211)JhumaB.K600769680Mastabandali902 : 6
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (207)MinaB.K280769680Mastabandali902 : 6
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 6
# Edit distance between (207)MinaB.K280769680Mastabandali902 and (209)DebuB.K500769680Mastabandali902 : 6
# Edit distance between (207)MinaB.K280769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 6
# Edit distance between (207)MinaB.K280769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 6
# Edit distance between (208)ManikaB.K140769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 6
# Edit distance between (209)DebuB.K500769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 6
# Edit distance between (182)ParashBista200769680Muli141 and (188)LaxmanBista180769680Muli141 : 7
# Edit distance between (185)DhurbaBista180769680Muli141 and (186)ParashBista190769680Muli141 : 7
# Edit distance between (185)DhurbaBista180769680Muli141 and (189)HikmatBista170769680Muli141 : 7
# Edit distance between (186)ParashBista190769680Muli141 and (189)HikmatBista170769680Muli141 : 7
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (205)BhimB.K80769680Mastabandali901 : 7
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (207)MinaB.K280769680Mastabandali902 : 7
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (204)SapanaB.K111769680Mastabandali902 : 7
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (205)BhimB.K80769680Mastabandali901 : 7
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (206)RamitaB.K70769680Mastabandali902 : 7
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 7
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (206)RamitaB.K70769680Mastabandali902 : 7
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (207)MinaB.K280769680Mastabandali902 : 7
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (206)RamitaB.K70769680Mastabandali902 : 7
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (209)DebuB.K500769680Mastabandali902 : 7
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 7
# Edit distance between (207)MinaB.K280769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 7
# Edit distance between (208)ManikaB.K140769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 7
# Edit distance between (209)DebuB.K500769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 7
# Edit distance between (209)DebuB.K500769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 7
# Edit distance between (210)TankB.K70769680Mastabandali901 and (212)TulsiB.K450769680Mastabandali902 : 7
# Edit distance between (211)JhumaB.K600769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 7
# Edit distance between (218)ManeB.K370769683Toli601 and (219)RenukaB.K320769683Toli602 : 7
# Edit distance between (148)NarayanPrasadTimilsena330769680kuika541 and (180)BishnuPrasadTimilsena330769680Kuika541 : 8
# Edit distance between (182)ParashBista200769680Muli141 and (185)DhurbaBista180769680Muli141 : 8
# Edit distance between (182)ParashBista200769680Muli141 and (187)KhemBista190769680Muli141 : 8
# Edit distance between (182)ParashBista200769680Muli141 and (189)HikmatBista170769680Muli141 : 8
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (203)SaritaB.K210769680Mastabandali902 : 8
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (209)DebuB.K500769680Mastabandali902 : 8
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (210)TankB.K70769680Mastabandali901 : 8
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (211)JhumaB.K600769680Mastabandali902 : 8
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (208)ManikaB.K140769680Mastabandali902 : 8
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (209)DebuB.K500769680Mastabandali902 : 8
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (211)JhumaB.K600769680Mastabandali902 : 8
# Edit distance between (202)KaranB.K270769680Mastabandali901 and (212)TulsiB.K450769680Mastabandali902 : 8
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (205)BhimB.K80769680Mastabandali901 : 8
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (209)DebuB.K500769680Mastabandali902 : 8
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 8
# Edit distance between (203)SaritaB.K210769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 8
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (210)TankB.K70769680Mastabandali901 : 8
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (211)JhumaB.K600769680Mastabandali902 : 8
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (208)ManikaB.K140769680Mastabandali902 : 8
# Edit distance between (205)BhimB.K80769680Mastabandali901 and (212)TulsiB.K450769680Mastabandali902 : 8
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (209)DebuB.K500769680Mastabandali902 : 8
# Edit distance between (206)RamitaB.K70769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 8
# Edit distance between (208)ManikaB.K140769680Mastabandali902 and (209)DebuB.K500769680Mastabandali902 : 8
# Edit distance between (208)ManikaB.K140769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 8
# Edit distance between (210)TankB.K70769680Mastabandali901 and (211)JhumaB.K600769680Mastabandali902 : 8
# Edit distance between (182)ParashBista200769680Muli141 and (191)NarBahadurBista620769680Muli141 : 9
# Edit distance between (186)ParashBista190769680Muli141 and (191)NarBahadurBista620769680Muli141 : 9
# Edit distance between (196)KarishmaShahi250769680Birpath652 and (197)SarswotiShahi101769680Birpath652 : 9
# Edit distance between (197)SarswotiShahi101769680Birpath652 and (198)SurjaShahi250769680Birpath652 : 9
# Edit distance between (199)TankDhami390769683Malutol241 and (200)NaurataDhami460769683Malutol242 : 9
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (206)RamitaB.K70769680Mastabandali902 : 9
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (208)ManikaB.K140769680Mastabandali902 : 9
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (212)TulsiB.K450769680Mastabandali902 : 9
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (209)DebuB.K500769680Mastabandali902 : 9
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (212)TulsiB.K450769680Mastabandali902 : 9
# Edit distance between (187)KhemBista190769680Muli141 and (194)KhemRajRegmi330769680Muli141 : 10
# Edit distance between (188)LaxmanBista180769680Muli141 and (191)NarBahadurBista620769680Muli141 : 10
# Edit distance between (195)SherBahadurShahi280769680Birpath651 and (198)SurjaShahi250769680Birpath652 : 10
# Edit distance between (201)KeshabB.K220769680Mastabandali901 and (204)SapanaB.K111769680Mastabandali902 : 10
# Edit distance between (204)SapanaB.K111769680Mastabandali902 and (205)BhimB.K80769680Mastabandali901 : 10
# ..........Dataset within the edit distance with unique id.............
# [(121, 'TekBahadurBista280769680Bajuda241'), (122, 'TekBahadurBista280769680Bajuda241'), (148, 'NarayanPrasadTimilsena330769680kuika541'), (180, 'BishnuPrasadTimilsena330769680Kuika541'), (182, 'ParashBista200769680Muli141'), (185, 'DhurbaBista180769680Muli141'), (186, 'ParashBista190769680Muli141'), (187, 'KhemBista190769680Muli141'), (188, 'LaxmanBista180769680Muli141'), (189, 'HikmatBista170769680Muli141'), (191, 'NarBahadurBista620769680Muli141'), (194, 'KhemRajRegmi330769680Muli141'), (195, 'SherBahadurShahi280769680Birpath651'), (198, 'SurjaShahi250769680Birpath652'), (196, 'KarishmaShahi250769680Birpath652'), (197, 'SarswotiShahi101769680Birpath652'), (199, 'TankDhami390769683Malutol241'), (200, 'NaurataDhami460769683Malutol242'), (201, 'KeshabB.K220769680Mastabandali901'), (202, 'KaranB.K270769680Mastabandali901'), (203, 'SaritaB.K210769680Mastabandali902'), (204, 'SapanaB.K111769680Mastabandali902'), (205, 'BhimB.K80769680Mastabandali901'), (206, 'RamitaB.K70769680Mastabandali902'), (207, 'MinaB.K280769680Mastabandali902'), (208, 'ManikaB.K140769680Mastabandali902'), (209, 'DebuB.K500769680Mastabandali902'), (210, 'TankB.K70769680Mastabandali901'), (211, 'JhumaB.K600769680Mastabandali902'), (212, 'TulsiB.K450769680Mastabandali902'), (218, 'ManeB.K370769683Toli601'), (219, 'RenukaB.K320769683Toli602')]
# Count:  32
# Total duplicates:  2
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Dell\AppData\Local\Temp\ipykernel_18840\555739685.py", line 100, in upload_file
#     canvas.config(scrollregion=canvas.bbox("all"))
# AttributeError: 'NoneType' object has no attribute 'config'
